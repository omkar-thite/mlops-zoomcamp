# %%
import math 

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_parquet('data/green_tripdata_2021-01.parquet')
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1         2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2         2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3         2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4         2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            43           151              1.0           1.01
# 1         1.0           166           239              1.0           2.53
# 2         1.0            41            42              1.0           1.12
# 3         1.0           168            75              1.0           1.99
# 4         2.0           265           265              3.0           0.00
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# ...

# %%
# Function that does everythin above: Can be used for validation dataset

def process_dataset(path):
    df = pd.read_parquet(path)
    df = df[df.trip_type == 2]
    
    # Calculate duration
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    
    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    
    # Convert datetime to minutes
    df.duration = df.duration.apply(lambda x: x.total_seconds()/60.0)
    
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    df[categorical] = df[categorical].astype(str)
    
    train_dicts= df[categorical + numerical].to_dict(orient='records')
    dv = DictVectorizer()  # Turns a dictionary into vector
    
    X_train = dv.fit_transform(train_dicts)
    
    target = 'duration'
    
    y_train = df[target].values

    return X_train, y_train

# %% [markdown]
# Green Trips data dicitonary (features and their info) at : [link](https://www.nyc.gov/assets/tlc/downloads/pdf/data_dictionary_trip_records_green.pdf)

# %% [markdown]
# trip_type:
# - 1 : street hail rides
# - 2 : 'Dispatch' rides, assigned by app.
#
# We'll analyze app only rides, i.e. where trip_type = 2.

# %%
df = df[df.trip_type == 2]
df.head()
# Out:
#     VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 6          2  2021-01-01 00:19:14   2021-01-01 00:19:21                  N
# 15         2  2021-01-01 00:29:05   2021-01-01 00:29:07                  N
# 30         2  2021-01-01 00:35:29   2021-01-01 00:55:15                  N
# 43         2  2021-01-01 23:12:41   2021-01-02 01:13:53                  N
# 45         2  2021-01-01 01:49:29   2021-01-01 01:49:33                  N
#
#     RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 6          5.0           265           265              1.0           0.00
# 15         5.0            42           264              1.0           0.00
# 30         5.0            74           247              1.0           3.64
# 43         5.0            95            82              1.0           0.00
# 45         5.0           244           244              5.0           0.02
#
# ...

# %%
# Calculate duration
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime

# Convert datetime to minutes
df.duration = df.duration.apply(lambda x: x.total_seconds()/60.0)
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 6             2  2021-01-01 00:19:14   2021-01-01 00:19:21                  N
# 15            2  2021-01-01 00:29:05   2021-01-01 00:29:07                  N
# 30            2  2021-01-01 00:35:29   2021-01-01 00:55:15                  N
# 43            2  2021-01-01 23:12:41   2021-01-02 01:13:53                  N
# 45            2  2021-01-01 01:49:29   2021-01-01 01:49:33                  N
# ...         ...                  ...                   ...                ...
# 40363         2  2021-01-31 19:26:20   2021-01-31 19:35:47                  N
# 40364         2  2021-01-31 19:44:54   2021-01-31 20:19:56                  N
# 40377         2  2021-01-31 20:09:41   2021-01-31 20:10:21                  N
# 40394         2  2021-01-31 20:38:42   2021-01-31 20:38:45                  N
# 40430         2  2021-01-31 21:48:08   2021-01-31 22:11:17                  N
#
# ...

# %% [markdown]
# `duration` can be our target variable.

# %%
# See distribution of duration

sns.distplot(df.duration)
# Out:
# /tmp/ipykernel_12313/637941372.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.duration)
# <Axes: xlabel='duration', ylabel='Density'>

# %% [markdown]
# Not possible to see whats happening due to long tail.

# %%
df.duration.describe(percentiles=[.95, .98, .99])
# Out:
# count    1238.000000
# mean       18.305493
# std       108.364382
# min         0.000000
# 50%         1.666667
# 95%        35.604167
# 98%        59.339333
# 99%       149.837833
# max      1416.100000
# Name: duration, dtype: float64

# %% [markdown]
# Most of the data 98% is under 1 hour (59 minutes) which make sense for business to focus on.

# %%
df = df[(df.duration >= 1) & (df.duration <= 60)]
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 30            2  2021-01-01 00:35:29   2021-01-01 00:55:15                  N
# 53            2  2021-01-01 01:54:51   2021-01-01 02:15:35                  N
# 69            2  2021-01-01 02:42:49   2021-01-01 02:50:59                  N
# 88            2  2021-01-01 04:52:02   2021-01-01 05:05:01                  N
# 96            2  2021-01-01 05:52:43   2021-01-01 05:58:02                  N
# ...         ...                  ...                   ...                ...
# 40324         2  2021-01-31 18:42:52   2021-01-31 19:08:44                  N
# 40352         1  2021-01-31 19:32:22   2021-01-31 19:50:16                  N
# 40363         2  2021-01-31 19:26:20   2021-01-31 19:35:47                  N
# 40364         2  2021-01-31 19:44:54   2021-01-31 20:19:56                  N
# 40430         2  2021-01-31 21:48:08   2021-01-31 22:11:17                  N
#
# ...

# %%
#categorical = ['VendorID', 'store_and_fwd_flag', 'RatecodeID', 'payment_type', 'trip_type']
categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

# %% [markdown]
# ### Train model

# %%
df[categorical].dtypes
# Out:
# PULocationID    int64
# DOLocationID    int64
# dtype: object

# %% [markdown]
# We will use dictionary vectorizer for one hot encoding of cateogircal variables. for that we need categoical types be of object type and not int.

# %%
# convert int to str 
df[categorical] = df[categorical].astype(str)

# %%
df.dtypes
# Out:
# VendorID                          int64
# lpep_pickup_datetime     datetime64[us]
# lpep_dropoff_datetime    datetime64[us]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                     object
# DOLocationID                     object
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                        object
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# duration                        float64
# dtype: object

# %%
# Turn dataframes to dicts

df[categorical + numerical]
# Out:
#       PULocationID DOLocationID  trip_distance
# 30              74          247           3.64
# 53              74           94           5.82
# 69             136          241           0.57
# 88             247           75           3.43
# 96               7            7           0.65
# ...            ...          ...            ...
# 40324           69          213           5.40
# 40352           82          129           2.40
# 40363          167          248           1.31
# 40364          147          147           6.97
# 40430           69          242           6.32
#
# [640 rows x 3 columns]

# %%
train_dicts= df[categorical + numerical].to_dict(orient='records')

# %%
dv = DictVectorizer()  # Turns a dictionary into vector

# %%
X_train = dv.fit_transform(train_dicts)
X_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1920 stored elements and shape (640, 236)>

# %% [markdown]
# This is feature matrix we'll use to train our model.

# %% [markdown]
# Each locarion is a feature, while trip_distance being numerical DictVectorizer do not attempt to.

# %%
target = 'duration'

y_train = df[target].values

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_train)

# %%
# Visualize predictions
sns.distplot(y_pred, label='predictions')
sns.distplot(y_train, label='training')
plt.legend()
# Out:
# /tmp/ipykernel_12313/1909901698.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred, label='predictions')
# /tmp/ipykernel_12313/1909901698.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train, label='training')

# %%
math.sqrt(mean_squared_error(y_train, y_pred))
# Out:
# 4.803126149499836

# %% [markdown]
#  Model is wrong on average by 4.8 minutes. Lets see what it does on validation datset:
#  Validation dataset is Feb 23 dataset.

# %%
X_val, y_val = process_dataset('data/green_tripdata_2021-02.parquet')
y_pred = model.predict(X_val)

math.sqrt(mean_squared_error(y_val, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 2
#       1 X_val, y_val = process_dataset('data/green_tripdata_2021-02.parquet')
# ----> 2 y_pred = model.predict(X_val)
#       4 math.sqrt(mean_squared_error(y_val, y_pred))
#
# File /home/noobdv18/projects/mlops-zoomcamp/mlops/lib/python3.10/site-packages/sklearn/linear_model/_base.py:297, in LinearModel.predict(self, X)
#     283 def predict(self, X):
#     284     """
#     285     Predict using the linear model.
#     286
#    (...)
#     295         Returns predicted values.
#     296     """
# --> 297     return self._decision_function(X)
#
# File /home/noobdv18/projects/mlops-zoomcamp/mlops/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:1148, in ElasticNet._decision_function(self, X)
#    1146 check_is_fitted(self)
#    1147 if sparse.issparse(X):
# ...

# %%
# Use Lasso regression: Linear regression with regularization

model = Lasso()
model.fit(X_train, y_train)

y_pred = model.predict(X_train)

math.sqrt(mean_squared_error(y_train, y_pred))
# Out:
# 7.697953300324062
